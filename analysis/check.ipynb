# %%
import numpy as np

# %%
dat=np.load('/home/maria/LuckyMouse2/pixel_transformer_neuro/data/processed/hybrid_neural_responses_reduced.npy')

# %%
import matplotlib.pyplot as plt

plt.hist(dat.flatten()/50,bins=50)
# Out:
# (array([1.098585e+06, 1.218797e+06, 8.573570e+05, 5.153760e+05,
#         3.006460e+05, 1.836520e+05, 1.184230e+05, 8.032900e+04,
#         5.697000e+04, 4.186300e+04, 3.151900e+04, 2.377600e+04,
#         1.848900e+04, 1.469600e+04, 1.154200e+04, 9.205000e+03,
#         7.303000e+03, 6.075000e+03, 4.752000e+03, 3.877000e+03,
#         3.177000e+03, 2.590000e+03, 2.220000e+03, 1.956000e+03,
#         1.515000e+03, 1.356000e+03, 1.157000e+03, 1.052000e+03,
#         9.490000e+02, 7.730000e+02, 7.490000e+02, 6.350000e+02,
#         5.720000e+02, 5.300000e+02, 8.610000e+02, 0.000000e+00,
#         4.240000e+02, 3.630000e+02, 2.880000e+02, 3.130000e+02,
#         4.960000e+02, 0.000000e+00, 2.360000e+02, 2.030000e+02,
#         1.950000e+02, 1.680000e+02, 2.820000e+02, 0.000000e+00,
#         1.470000e+02, 2.230000e+02]),
#  array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#         0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#         0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#         0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#         0.88, 0.9 , 0.92, 0.94, 0.96, 0.98, 1.  ]),
#  <BarContainer object of 50 artists>)
